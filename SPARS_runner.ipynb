# %%
# runner.py
import json
import os
from datetime import datetime
from typing import Any, Dict

import torch as T

from SPARS.Utils import get_logger, log_output
from SPARS.Simulator.Simulator import Simulator, run_simulation

# IMPORTANT: load Gym config BEFORE importing the env so monkey-patches apply
from SPARS.Gym import config          # your pluggable Gym setup
from SPARS.Gym import utils as G
from SPARS.Gym.gym import HPCGymEnv

DEFAULT_CFG_PATH = "simulator_config.yaml"

# %%
def _load_config(path: str = DEFAULT_CFG_PATH) -> Dict[str, Any]:
    """
    Load YAML or JSON config from a fixed path. If the file doesn't exist,
    fall back to internal defaults (keeps the runner usable out of the box).
    """
    import pathlib
    p = pathlib.Path(path)
    if p.exists():
        if p.suffix.lower() in {".yml", ".yaml"}:
            import yaml  # requires PyYAML
            with open(p, "r", encoding="utf-8") as f:
                return yaml.safe_load(f)
        with open(p, "r", encoding="utf-8") as f:
            return json.load(f)

    # Fallback defaults (edit these if you want different out-of-the-box behavior)
    return {
        "paths": {
            "workload": "workloads/generated.json",
            "platform": "platforms/generated.json",
            "output":   "results/generated",
        },
        "run": {
            "algorithm": "fcfs_normal",
            "overrun_policy": "continue",
            "timeout": None,
            "start_time": 0,  # epoch int, or "now", or "YYYY-MM-DD HH:MM:SS"
        },
        "rl": {
            "enabled": False,
            "type": "discrete",   # "discrete" | "continuous"
            "dt": 1800,           # required for discrete
            "device": "auto",     # "auto" | "cpu" | "cuda"
            "learning_rate": 3e-4,
            "epochs": 10,
            "num_nodes": 16,
            "obs_dim": 11,
            "act_dim": 1,
        },
        "logging": {
            "level": "INFO",
            "file": "results/simulation.log",
        },
    }


def _choose_device(pref: str) -> str:
    if pref == "auto":
        return "cuda" if T.cuda.is_available() else "cpu"
    return pref


def _parse_start_time(value) -> int:
    """
    Accepts:
      - int/float epoch
      - "now"
      - "YYYY-MM-DD HH:MM:SS"
    Returns epoch seconds (int).
    """
    if isinstance(value, (int, float)):
        return int(value)
    if isinstance(value, str):
        if value.lower() == "now":
            return int(datetime.now().timestamp())
        try:
            t = datetime.strptime(value, "%Y-%m-%d %H:%M:%S")
            return int(t.timestamp())
        except ValueError:
            raise ValueError(
                "run.start_time must be epoch int, 'now', or 'YYYY-MM-DD HH:MM:SS'"
            )
    raise TypeError("Unsupported start_time type")


# ---------------------------
# Helpers for flexible agent construction (ONLY addition)
# ---------------------------
def _load_object(spec: str):
    """Load 'pkg.mod:Obj' or 'pkg.mod.Obj' into a Python object."""
    import importlib
    if ":" in spec:
        mod, name = spec.split(":", 1)
    else:
        mod, _, name = spec.rpartition(".")
        if not mod:
            raise ValueError(f"Bad import path: {spec}")
    return getattr(importlib.import_module(mod), name)


def _instantiate_with_flexible_kwargs(cls, params: dict, *, positional_first: str | None = None):
    """
    Instantiate `cls` with kwargs in `params`. If the constructor needs a first positional
    argument (e.g., optimizer 'params'), set positional_first='params'.
    Filters unknown kwargs automatically when possible.
    """
    import inspect
    params = dict(params or {})

    def _call(p: dict):
        if positional_first and positional_first in p:
            pf = p.pop(positional_first)
            try:
                return cls(pf, **p)
            finally:
                p[positional_first] = pf
        return cls(**p)

    try:
        return _call(params)
    except TypeError:
        # Filter unknown kwargs unless ctor accepts **kwargs
        sig = None
        try:
            sig = inspect.signature(cls.__init__)
            has_varkw = any(
                a.kind == inspect.Parameter.VAR_KEYWORD for a in sig.parameters.values())
            if has_varkw:
                raise
            allowed = {k for k in sig.parameters if k != "self"}
            filtered = {k: v for k, v in params.items() if k in allowed}
            return _call(filtered)
        except Exception:
            raise


def _build_agent(rl_cfg: dict, device: str):
    """
    Build agent and optimizer ENTIRELY from cfg['rl']['agent'] with flexible params.
    - No hard-coded keys like obs_dim/act_dim are injected.
    - 'device' handling:
        * if agent.params.device == "auto" -> resolve with _choose_device
        * if agent.params.device missing   -> set to resolved device
        * if agent ctor doesn't accept 'device', it's filtered; if it's an nn.Module,
          we still move it to the device afterward.
    """
    agent_cfg = rl_cfg.get("agent") or {}

    # ----- Agent class -----
    AgentClass = _load_object(agent_cfg.get(
        "class", "RL_Agent.SPARS.agent:ActorCriticMLP"))
    params = dict(agent_cfg.get("params") or {})

    cfg_device = params.get("device", rl_cfg.get("device", "auto"))
    final_device = _choose_device(
        cfg_device if cfg_device is not None else "auto")

    if "device" not in params or str(params.get("device")).lower() == "auto":
        params["device"] = final_device

    model = _instantiate_with_flexible_kwargs(AgentClass, params)

    # Ensure nn.Module is moved even if ctor ignored 'device'
    try:
        import torch.nn as nn
        if isinstance(model, nn.Module):
            model.to(final_device)
    except Exception:
        pass

    # ----- Optimizer -----
    opt_cfg = agent_cfg.get("optimizer") or {}
    OptClass = _load_object(opt_cfg.get("class", "torch.optim:Adam"))

    opt_params = dict(opt_cfg.get("params") or {})
    if "lr" not in opt_params and "learning_rate" in rl_cfg:
        opt_params["lr"] = float(rl_cfg["learning_rate"])

    optimizer = _instantiate_with_flexible_kwargs(
        OptClass,
        {"params": model.parameters() if hasattr(model, "parameters")
         else model, **opt_params},
        positional_first="params",
    )

    return model, optimizer
# ---------------------------

# %%
def main():
    cfg = _load_config(DEFAULT_CFG_PATH)

    # --- Logging ---
    logger = get_logger(
        "runner",
        level=cfg["logging"].get("level", "INFO"),
        log_file=cfg["logging"].get("file", "results/simulation.log"),
    )

    # --- Config Unpack ---
    workload_path = cfg["paths"]["workload"]
    platform_path = cfg["paths"]["platform"]
    output_path = cfg["paths"]["output"]

    algorithm = cfg["run"]["algorithm"]
    overrun_policy = cfg["run"].get("overrun_policy", "continue")
    timeout = cfg["run"].get("timeout", None)
    start_time = _parse_start_time(cfg["run"].get("start_time", 0))

    rl_enabled = bool(cfg["rl"].get("enabled", False))
    rl_type = cfg["rl"].get("type", "discrete") if rl_enabled else None
    rl_dt = cfg["rl"].get("dt", None) if rl_type == "discrete" else None
    device = _choose_device(cfg["rl"].get("device", "auto"))

    # === RL parameters ===
    learning_rate = float(cfg["rl"].get("learning_rate", 3e-4))
    epochs = int(cfg["rl"].get("epochs", 10))
    num_nodes = int(cfg["rl"].get("num_nodes", 16))
    obs_dim = int(cfg["rl"].get("obs_dim", 11))
    act_dim = int(cfg["rl"].get("act_dim", 1))

    if rl_enabled and rl_type == "discrete" and rl_dt is None:
        raise RuntimeError("Discrete RL requires rl.dt in the config file.")

    if rl_enabled:
        # Build simulator from config (no CLI/args)
        simulator = Simulator.from_config(
            cfg,
            rl_kwargs={"rl_type": rl_type, "rl_dt": rl_dt},
        )
        env = HPCGymEnv(simulator, device)

        # === ONLY change below: agent is now built from config flexibly ===
        model, model_opt = _build_agent(cfg["rl"], device)

        for _ in range(epochs):
            # reset per epoch
            simulator = Simulator.from_config(
                cfg,
                rl_kwargs={"rl_type": rl_type, "rl_dt": rl_dt},
            )
            env.reset(simulator)
            env.simulator.start_simulator()
            observation = env.get_observation()

            memory_features = []
            memory_masks = []
            memory_actions = []
            memory_rewards = []

            while env.simulator.is_running:
                features_, mask_ = observation
                features_ = features_.to(device)

                # your policy/value forward

                # --- SPARS ---
                # logits, values = model(features_)

                # --- Thomas Reshape ---
                features_reshaped = features_.reshape(1, num_nodes, 11)
                logits, values = model(features_reshaped)

                next_observation, reward, done = env.step(logits)

                # store experience (detach from graph)
                memory_actions.append(logits.detach())
                memory_features.append(features_.detach())
                memory_masks.append(mask_.detach())
                memory_rewards.append(reward.detach() if isinstance(reward, T.Tensor)
                                      else T.tensor(float(reward)))

                saved_experiences = (
                    memory_actions, memory_features, memory_masks, memory_rewards
                )

                # learner chosen in SPARS.Gym.config (utils.G.learn)
                G.learn(model, model_opt, done,
                        saved_experiences, next_observation)

                observation = next_observation

        log_output(env.simulator, output_path)

        # --- Save agent checkpoint ---
        os.makedirs(output_path, exist_ok=True)
        ckpt = {
            "agent_class": f"{model.__class__.__module__}:{model.__class__.__name__}",
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": model_opt.state_dict(),
            "rl_config": cfg.get("rl", {}),
            "epochs_trained": epochs,
        }
        ckpt_path = os.path.join(output_path, "agent_checkpoint.pt")
        T.save(ckpt, ckpt_path)
        logger.info(f"Saved agent checkpoint to: {ckpt_path}")

    else:
        simulator = Simulator.from_config(cfg)
        run_simulation(simulator, output_path)

main()
# Out:
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=0.00] type=simulation_start
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=9.00] job_id=1 type=arrival res=5 subtime=9 reqtime=47 runtime=50 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=9.00] job_id=1 type=execution_start subtime=9 runtime=50 reqtime=47 res=5 nodes=[0, 1, 2, 3, 4]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=14.00] job_id=2 type=arrival res=3 subtime=14 reqtime=34 runtime=34 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=14.00] job_id=2 type=execution_start subtime=14 runtime=34 reqtime=34 res=3 nodes=[5, 6, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=19.00] job_id=3 type=arrival res=5 subtime=19 reqtime=134 runtime=135 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=19.00] job_id=3 type=execution_start subtime=19 runtime=135 reqtime=134 res=5 nodes=[8, 9, 10, 11, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=24.00] job_id=4 type=arrival res=3 subtime=24 reqtime=104 runtime=105 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=24.00] job_id=4 type=execution_start subtime=24 runtime=105 reqtime=104 res=3 nodes=[13, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=26.00] job_id=5 type=arrival res=3 subtime=26 reqtime=75 runtime=75 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=34.00] job_id=6 type=arrival res=4 subtime=34 reqtime=75 runtime=75 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=41.00] job_id=7 type=arrival res=5 subtime=41 reqtime=92 runtime=91 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=43.00] job_id=8 type=arrival res=2 subtime=43 reqtime=112 runtime=114 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=48.00] job_id=2 type=execution_finished nodes=[5, 6, 7] start_time=14 subtime=14 actual_finish_time=48.0 req_finish_time=48.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=48.00] job_id=5 type=execution_start subtime=26 runtime=75 reqtime=75 res=3 nodes=[5, 6, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=52.00] job_id=9 type=arrival res=5 subtime=52 reqtime=67 runtime=67 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=56.00] job_id=1 type=execution_finished nodes=[0, 1, 2, 3, 4] start_time=9 subtime=9 actual_finish_time=59.0 req_finish_time=56.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=56.00] job_id=6 type=execution_start subtime=34 runtime=75 reqtime=75 res=4 nodes=[0, 1, 2, 3]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=62.00] job_id=10 type=arrival res=6 subtime=62 reqtime=88 runtime=89 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=67.00] job_id=11 type=arrival res=3 subtime=67 reqtime=55 runtime=55 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=67.00] job_id=12 type=arrival res=4 subtime=67 reqtime=48 runtime=49 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=71.00] job_id=13 type=arrival res=4 subtime=71 reqtime=79 runtime=79 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=72.00] job_id=14 type=arrival res=3 subtime=72 reqtime=46 runtime=47 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=89.00] job_id=15 type=arrival res=3 subtime=89 reqtime=97 runtime=97 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=90.00] job_id=16 type=arrival res=4 subtime=90 reqtime=80 runtime=81 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=90.00] job_id=17 type=arrival res=3 subtime=90 reqtime=95 runtime=97 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=92.00] job_id=18 type=arrival res=4 subtime=92 reqtime=111 runtime=110 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=101.00] job_id=19 type=arrival res=3 subtime=101 reqtime=69 runtime=70 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=117.00] job_id=20 type=arrival res=3 subtime=117 reqtime=71 runtime=70 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=120.00] job_id=21 type=arrival res=3 subtime=120 reqtime=98 runtime=98 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=122.00] job_id=22 type=arrival res=5 subtime=122 reqtime=42 runtime=42 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=123.00] job_id=5 type=execution_finished nodes=[5, 6, 7] start_time=48.0 subtime=26 actual_finish_time=123.0 req_finish_time=123.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=123.00] job_id=8 type=execution_start subtime=43 runtime=114 reqtime=112 res=2 nodes=[4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=126.00] job_id=23 type=arrival res=5 subtime=126 reqtime=127 runtime=128 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=128.00] job_id=4 type=execution_finished nodes=[13, 14, 15] start_time=24 subtime=24 actual_finish_time=129.0 req_finish_time=128.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=128.00] job_id=7 type=execution_start subtime=41 runtime=91 reqtime=92 res=5 nodes=[6, 7, 13, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=129.00] job_id=24 type=arrival res=2 subtime=129 reqtime=138 runtime=136 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=131.00] job_id=6 type=execution_finished nodes=[0, 1, 2, 3] start_time=56.0 subtime=34 actual_finish_time=131.0 req_finish_time=131.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=131.00] job_id=11 type=execution_start subtime=67 runtime=55 reqtime=55 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=136.00] job_id=25 type=arrival res=4 subtime=136 reqtime=77 runtime=76 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=139.00] job_id=26 type=arrival res=2 subtime=139 reqtime=96 runtime=97 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=148.00] job_id=27 type=arrival res=3 subtime=148 reqtime=63 runtime=63 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=151.00] job_id=28 type=arrival res=3 subtime=151 reqtime=35 runtime=35 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=152.00] job_id=29 type=arrival res=5 subtime=152 reqtime=46 runtime=46 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=152.00] job_id=30 type=arrival res=4 subtime=152 reqtime=82 runtime=83 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=153.00] job_id=3 type=execution_finished nodes=[8, 9, 10, 11, 12] start_time=19 subtime=19 actual_finish_time=154.0 req_finish_time=153.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=153.00] job_id=9 type=execution_start subtime=52 runtime=67 reqtime=67 res=5 nodes=[3, 8, 9, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=155.00] job_id=31 type=arrival res=4 subtime=155 reqtime=18 runtime=18 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=156.00] job_id=32 type=arrival res=3 subtime=156 reqtime=4 runtime=5 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=160.00] job_id=33 type=arrival res=3 subtime=160 reqtime=111 runtime=110 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=166.00] job_id=34 type=arrival res=3 subtime=166 reqtime=58 runtime=58 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=174.00] job_id=35 type=arrival res=3 subtime=174 reqtime=161 runtime=162 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=174.00] job_id=36 type=arrival res=3 subtime=174 reqtime=52 runtime=52 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=174.00] job_id=37 type=arrival res=5 subtime=174 reqtime=35 runtime=34 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=186.00] job_id=38 type=arrival res=2 subtime=186 reqtime=78 runtime=77 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=186.00] job_id=39 type=arrival res=3 subtime=186 reqtime=56 runtime=58 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=186.00] job_id=11 type=execution_finished nodes=[0, 1, 2] start_time=131.0 subtime=67 actual_finish_time=186.0 req_finish_time=186.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=186.00] job_id=14 type=execution_start subtime=72 runtime=47 reqtime=46 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=187.00] job_id=40 type=arrival res=4 subtime=187 reqtime=113 runtime=114 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=190.00] job_id=41 type=arrival res=4 subtime=190 reqtime=100 runtime=100 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=191.00] job_id=42 type=arrival res=3 subtime=191 reqtime=105 runtime=103 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=202.00] job_id=43 type=arrival res=2 subtime=202 reqtime=63 runtime=64 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=208.00] job_id=44 type=arrival res=4 subtime=208 reqtime=73 runtime=73 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=215.00] job_id=45 type=arrival res=4 subtime=215 reqtime=145 runtime=145 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=219.00] job_id=46 type=arrival res=7 subtime=219 reqtime=36 runtime=36 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=219.00] job_id=7 type=execution_finished nodes=[6, 7, 13, 14, 15] start_time=128.0 subtime=41 actual_finish_time=219.0 req_finish_time=220.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=219.00] job_id=10 type=execution_start subtime=62 runtime=89 reqtime=88 res=6 nodes=[6, 7, 12, 13, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=220.00] job_id=9 type=execution_finished nodes=[3, 8, 9, 10, 11] start_time=153.0 subtime=52 actual_finish_time=220.0 req_finish_time=220.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=220.00] job_id=12 type=execution_start subtime=67 runtime=49 reqtime=48 res=4 nodes=[3, 8, 9, 10]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=223.00] job_id=47 type=arrival res=4 subtime=223 reqtime=86 runtime=85 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=232.00] job_id=14 type=execution_finished nodes=[0, 1, 2] start_time=186 subtime=72 actual_finish_time=233.0 req_finish_time=232.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=232.00] job_id=13 type=execution_start subtime=71 runtime=79 reqtime=79 res=4 nodes=[0, 1, 2, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=233.00] job_id=48 type=arrival res=2 subtime=233 reqtime=57 runtime=58 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=234.00] job_id=49 type=arrival res=4 subtime=234 reqtime=43 runtime=46 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=235.00] job_id=50 type=arrival res=4 subtime=235 reqtime=122 runtime=122 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=235.00] job_id=8 type=execution_finished nodes=[4, 5] start_time=123.0 subtime=43 actual_finish_time=237.0 req_finish_time=235.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=235.00] job_id=24 type=execution_start subtime=129 runtime=136 reqtime=138 res=2 nodes=[4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=243.00] job_id=51 type=arrival res=3 subtime=243 reqtime=93 runtime=95 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=243.00] job_id=52 type=arrival res=4 subtime=243 reqtime=46 runtime=46 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=248.00] job_id=53 type=arrival res=3 subtime=248 reqtime=115 runtime=115 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=248.00] job_id=54 type=arrival res=4 subtime=248 reqtime=98 runtime=97 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=256.00] job_id=55 type=arrival res=2 subtime=256 reqtime=98 runtime=99 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=268.00] job_id=12 type=execution_finished nodes=[3, 8, 9, 10] start_time=220.0 subtime=67 actual_finish_time=269.0 req_finish_time=268.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=268.00] job_id=15 type=execution_start subtime=89 runtime=97 reqtime=97 res=3 nodes=[3, 8, 9]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=270.00] job_id=56 type=arrival res=1 subtime=270 reqtime=147 runtime=146 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=270.00] job_id=57 type=arrival res=4 subtime=270 reqtime=77 runtime=77 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=270.00] job_id=58 type=arrival res=3 subtime=270 reqtime=113 runtime=113 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=270.00] job_id=59 type=arrival res=5 subtime=270 reqtime=102 runtime=103 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=270.00] job_id=56 type=execution_start subtime=270 runtime=146 reqtime=147 res=1 nodes=[10]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=274.00] job_id=60 type=arrival res=1 subtime=274 reqtime=176 runtime=175 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=277.00] job_id=61 type=arrival res=2 subtime=277 reqtime=53 runtime=53 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=279.00] job_id=62 type=arrival res=1 subtime=279 reqtime=57 runtime=56 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=287.00] job_id=63 type=arrival res=4 subtime=287 reqtime=93 runtime=93 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=288.00] job_id=64 type=arrival res=5 subtime=288 reqtime=64 runtime=64 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=289.00] job_id=65 type=arrival res=6 subtime=289 reqtime=58 runtime=56 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=295.00] job_id=66 type=arrival res=4 subtime=295 reqtime=117 runtime=117 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=303.00] job_id=67 type=arrival res=3 subtime=303 reqtime=88 runtime=89 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=306.00] job_id=68 type=arrival res=3 subtime=306 reqtime=72 runtime=71 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=307.00] job_id=10 type=execution_finished nodes=[6, 7, 12, 13, 14, 15] start_time=219 subtime=62 actual_finish_time=308.0 req_finish_time=307.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=307.00] job_id=16 type=execution_start subtime=90 runtime=81 reqtime=80 res=4 nodes=[6, 7, 12, 13]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=307.00] job_id=26 type=execution_start subtime=139 runtime=97 reqtime=96 res=2 nodes=[14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=311.00] job_id=69 type=arrival res=3 subtime=311 reqtime=95 runtime=95 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=311.00] job_id=13 type=execution_finished nodes=[0, 1, 2, 11] start_time=232.0 subtime=71 actual_finish_time=311.0 req_finish_time=311.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=311.00] job_id=17 type=execution_start subtime=90 runtime=97 reqtime=95 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=314.00] job_id=70 type=arrival res=2 subtime=314 reqtime=94 runtime=92 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=325.00] job_id=71 type=arrival res=5 subtime=325 reqtime=71 runtime=72 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=327.00] job_id=72 type=arrival res=3 subtime=327 reqtime=65 runtime=65 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=332.00] job_id=73 type=arrival res=3 subtime=332 reqtime=110 runtime=111 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=332.00] job_id=74 type=arrival res=3 subtime=332 reqtime=32 runtime=31 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=334.00] job_id=75 type=arrival res=4 subtime=334 reqtime=61 runtime=60 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=341.00] job_id=76 type=arrival res=3 subtime=341 reqtime=62 runtime=62 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=350.00] job_id=77 type=arrival res=3 subtime=350 reqtime=97 runtime=98 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=352.00] job_id=78 type=arrival res=2 subtime=352 reqtime=96 runtime=98 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=353.00] job_id=79 type=arrival res=3 subtime=353 reqtime=63 runtime=63 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=365.00] job_id=15 type=execution_finished nodes=[3, 8, 9] start_time=268.0 subtime=89 actual_finish_time=365.0 req_finish_time=365.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=365.00] job_id=18 type=execution_start subtime=92 runtime=110 reqtime=111 res=4 nodes=[3, 8, 9, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=371.00] job_id=24 type=execution_finished nodes=[4, 5] start_time=235 subtime=129 actual_finish_time=371.0 req_finish_time=373.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=371.00] job_id=38 type=execution_start subtime=186 runtime=77 reqtime=78 res=2 nodes=[4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=373.00] job_id=80 type=arrival res=5 subtime=373 reqtime=99 runtime=98 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=376.00] job_id=81 type=arrival res=4 subtime=376 reqtime=67 runtime=66 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=376.00] job_id=82 type=arrival res=5 subtime=376 reqtime=71 runtime=70 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=377.00] job_id=83 type=arrival res=3 subtime=377 reqtime=154 runtime=153 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=379.00] job_id=84 type=arrival res=3 subtime=379 reqtime=83 runtime=82 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=379.00] job_id=85 type=arrival res=3 subtime=379 reqtime=67 runtime=67 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=380.00] job_id=86 type=arrival res=3 subtime=380 reqtime=61 runtime=62 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=387.00] job_id=16 type=execution_finished nodes=[6, 7, 12, 13] start_time=307.0 subtime=90 actual_finish_time=388.0 req_finish_time=387.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=387.00] job_id=19 type=execution_start subtime=101 runtime=70 reqtime=69 res=3 nodes=[6, 7, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=399.00] job_id=87 type=arrival res=5 subtime=399 reqtime=82 runtime=84 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=403.00] job_id=26 type=execution_finished nodes=[14, 15] start_time=307.0 subtime=139 actual_finish_time=404.0 req_finish_time=403.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=403.00] job_id=20 type=execution_start subtime=117 runtime=70 reqtime=71 res=3 nodes=[13, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=406.00] job_id=17 type=execution_finished nodes=[0, 1, 2] start_time=311 subtime=90 actual_finish_time=408.0 req_finish_time=406.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=406.00] job_id=21 type=execution_start subtime=120 runtime=98 reqtime=98 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=416.00] job_id=56 type=execution_finished nodes=[10] start_time=270 subtime=270 actual_finish_time=416.0 req_finish_time=417.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=416.00] job_id=60 type=execution_start subtime=274 runtime=175 reqtime=176 res=1 nodes=[10]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=421.00] job_id=88 type=arrival res=5 subtime=421 reqtime=62 runtime=62 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=424.00] job_id=89 type=arrival res=3 subtime=424 reqtime=82 runtime=83 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=431.00] job_id=90 type=arrival res=4 subtime=431 reqtime=56 runtime=54 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=437.00] job_id=91 type=arrival res=6 subtime=437 reqtime=98 runtime=99 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=448.00] job_id=38 type=execution_finished nodes=[4, 5] start_time=371.0 subtime=186 actual_finish_time=448.0 req_finish_time=449.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=453.00] job_id=92 type=arrival res=3 subtime=453 reqtime=105 runtime=105 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=456.00] job_id=19 type=execution_finished nodes=[6, 7, 12] start_time=387.0 subtime=101 actual_finish_time=457.0 req_finish_time=456.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=456.00] job_id=22 type=execution_start subtime=122 runtime=42 reqtime=42 res=5 nodes=[4, 5, 6, 7, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=457.00] job_id=93 type=arrival res=2 subtime=457 reqtime=98 runtime=99 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=464.00] job_id=94 type=arrival res=4 subtime=464 reqtime=65 runtime=66 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=473.00] job_id=20 type=execution_finished nodes=[13, 14, 15] start_time=403.0 subtime=117 actual_finish_time=473.0 req_finish_time=474.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=473.00] job_id=43 type=execution_start subtime=202 runtime=64 reqtime=63 res=2 nodes=[13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=475.00] job_id=18 type=execution_finished nodes=[3, 8, 9, 11] start_time=365.0 subtime=92 actual_finish_time=475.0 req_finish_time=476.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=475.00] job_id=23 type=execution_start subtime=126 runtime=128 reqtime=127 res=5 nodes=[3, 8, 9, 11, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=477.00] job_id=95 type=arrival res=3 subtime=477 reqtime=59 runtime=60 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=481.00] job_id=96 type=arrival res=3 subtime=481 reqtime=75 runtime=74 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=482.00] job_id=97 type=arrival res=3 subtime=482 reqtime=98 runtime=99 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=483.00] job_id=98 type=arrival res=2 subtime=483 reqtime=51 runtime=49 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=497.00] job_id=99 type=arrival res=3 subtime=497 reqtime=57 runtime=58 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=498.00] job_id=22 type=execution_finished nodes=[4, 5, 6, 7, 12] start_time=456.0 subtime=122 actual_finish_time=498.0 req_finish_time=498.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=498.00] job_id=25 type=execution_start subtime=136 runtime=76 reqtime=77 res=4 nodes=[4, 5, 6, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=498.00] job_id=62 type=execution_start subtime=279 runtime=56 reqtime=57 res=1 nodes=[12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=504.00] job_id=100 type=arrival res=5 subtime=504 reqtime=53 runtime=51 profile=100 user_id=0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=504.00] job_id=21 type=execution_finished nodes=[0, 1, 2] start_time=406.0 subtime=120 actual_finish_time=504.0 req_finish_time=504.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=504.00] job_id=27 type=execution_start subtime=148 runtime=63 reqtime=63 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=536.00] job_id=43 type=execution_finished nodes=[13, 14] start_time=473.0 subtime=202 actual_finish_time=537.0 req_finish_time=536.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=554.00] job_id=62 type=execution_finished nodes=[12] start_time=498.0 subtime=279 actual_finish_time=554.0 req_finish_time=555.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=554.00] job_id=28 type=execution_start subtime=151 runtime=35 reqtime=35 res=3 nodes=[12, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=567.00] job_id=27 type=execution_finished nodes=[0, 1, 2] start_time=504 subtime=148 actual_finish_time=567.0 req_finish_time=567.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=567.00] job_id=32 type=execution_start subtime=156 runtime=5 reqtime=4 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=571.00] job_id=32 type=execution_finished nodes=[0, 1, 2] start_time=567.0 subtime=156 actual_finish_time=572.0 req_finish_time=571.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=571.00] job_id=48 type=execution_start subtime=233 runtime=58 reqtime=57 res=2 nodes=[0, 1]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=574.00] job_id=25 type=execution_finished nodes=[4, 5, 6, 7] start_time=498.0 subtime=136 actual_finish_time=574.0 req_finish_time=575.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=574.00] job_id=29 type=execution_start subtime=152 runtime=46 reqtime=46 res=5 nodes=[2, 4, 5, 6, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=589.00] job_id=28 type=execution_finished nodes=[12, 13, 14] start_time=554.0 subtime=151 actual_finish_time=589.0 req_finish_time=589.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=591.00] job_id=60 type=execution_finished nodes=[10] start_time=416.0 subtime=274 actual_finish_time=591.0 req_finish_time=592.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=591.00] job_id=30 type=execution_start subtime=152 runtime=83 reqtime=82 res=4 nodes=[10, 12, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=602.00] job_id=23 type=execution_finished nodes=[3, 8, 9, 11, 15] start_time=475.0 subtime=126 actual_finish_time=603.0 req_finish_time=602.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=602.00] job_id=31 type=execution_start subtime=155 runtime=18 reqtime=18 res=4 nodes=[3, 8, 9, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=620.00] job_id=29 type=execution_finished nodes=[2, 4, 5, 6, 7] start_time=574.0 subtime=152 actual_finish_time=620.0 req_finish_time=620.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=620.00] job_id=31 type=execution_finished nodes=[3, 8, 9, 11] start_time=602.0 subtime=155 actual_finish_time=620.0 req_finish_time=620.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=620.00] job_id=33 type=execution_start subtime=160 runtime=110 reqtime=111 res=3 nodes=[2, 3, 4]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=620.00] job_id=34 type=execution_start subtime=166 runtime=58 reqtime=58 res=3 nodes=[5, 6, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=620.00] job_id=35 type=execution_start subtime=174 runtime=162 reqtime=161 res=3 nodes=[8, 9, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=628.00] job_id=48 type=execution_finished nodes=[0, 1] start_time=571.0 subtime=233 actual_finish_time=629.0 req_finish_time=628.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=628.00] job_id=36 type=execution_start subtime=174 runtime=52 reqtime=52 res=3 nodes=[0, 1, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=673.00] job_id=30 type=execution_finished nodes=[10, 12, 13, 14] start_time=591.0 subtime=152 actual_finish_time=674.0 req_finish_time=673.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=673.00] job_id=55 type=execution_start subtime=256 runtime=99 reqtime=98 res=2 nodes=[10, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=678.00] job_id=34 type=execution_finished nodes=[5, 6, 7] start_time=620.0 subtime=166 actual_finish_time=678.0 req_finish_time=678.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=678.00] job_id=37 type=execution_start subtime=174 runtime=34 reqtime=35 res=5 nodes=[5, 6, 7, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=680.00] job_id=36 type=execution_finished nodes=[0, 1, 15] start_time=628.0 subtime=174 actual_finish_time=680.0 req_finish_time=680.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=680.00] job_id=39 type=execution_start subtime=186 runtime=58 reqtime=56 res=3 nodes=[0, 1, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=712.00] job_id=37 type=execution_finished nodes=[5, 6, 7, 13, 14] start_time=678.0 subtime=174 actual_finish_time=712.0 req_finish_time=713.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=712.00] job_id=40 type=execution_start subtime=187 runtime=114 reqtime=113 res=4 nodes=[5, 6, 7, 13]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=730.00] job_id=33 type=execution_finished nodes=[2, 3, 4] start_time=620.0 subtime=160 actual_finish_time=730.0 req_finish_time=731.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=730.00] job_id=41 type=execution_start subtime=190 runtime=100 reqtime=100 res=4 nodes=[2, 3, 4, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=736.00] job_id=39 type=execution_finished nodes=[0, 1, 15] start_time=680.0 subtime=186 actual_finish_time=738.0 req_finish_time=736.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=736.00] job_id=42 type=execution_start subtime=191 runtime=103 reqtime=105 res=3 nodes=[0, 1, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=771.00] job_id=55 type=execution_finished nodes=[10, 12] start_time=673.0 subtime=256 actual_finish_time=772.0 req_finish_time=771.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=781.00] job_id=35 type=execution_finished nodes=[8, 9, 11] start_time=620.0 subtime=174 actual_finish_time=782.0 req_finish_time=781.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=781.00] job_id=44 type=execution_start subtime=208 runtime=73 reqtime=73 res=4 nodes=[8, 9, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=825.00] job_id=40 type=execution_finished nodes=[5, 6, 7, 13] start_time=712.0 subtime=187 actual_finish_time=826.0 req_finish_time=825.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=825.00] job_id=45 type=execution_start subtime=215 runtime=145 reqtime=145 res=4 nodes=[5, 6, 7, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=830.00] job_id=41 type=execution_finished nodes=[2, 3, 4, 14] start_time=730.0 subtime=190 actual_finish_time=830.0 req_finish_time=830.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=839.00] job_id=42 type=execution_finished nodes=[0, 1, 15] start_time=736.0 subtime=191 actual_finish_time=839.0 req_finish_time=841.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=839.00] job_id=46 type=execution_start subtime=219 runtime=36 reqtime=36 res=7 nodes=[0, 1, 2, 3, 4, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=854.00] job_id=44 type=execution_finished nodes=[8, 9, 10, 11] start_time=781.0 subtime=208 actual_finish_time=854.0 req_finish_time=854.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=854.00] job_id=47 type=execution_start subtime=223 runtime=85 reqtime=86 res=4 nodes=[8, 9, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=875.00] job_id=46 type=execution_finished nodes=[0, 1, 2, 3, 4, 13, 14] start_time=839.0 subtime=219 actual_finish_time=875.0 req_finish_time=875.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=875.00] job_id=49 type=execution_start subtime=234 runtime=46 reqtime=43 res=4 nodes=[0, 1, 2, 3]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=875.00] job_id=50 type=execution_start subtime=235 runtime=122 reqtime=122 res=4 nodes=[4, 13, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=918.00] job_id=49 type=execution_finished nodes=[0, 1, 2, 3] start_time=875.0 subtime=234 actual_finish_time=921.0 req_finish_time=918.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=918.00] job_id=51 type=execution_start subtime=243 runtime=95 reqtime=93 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=939.00] job_id=47 type=execution_finished nodes=[8, 9, 10, 11] start_time=854.0 subtime=223 actual_finish_time=939.0 req_finish_time=940.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=939.00] job_id=52 type=execution_start subtime=243 runtime=46 reqtime=46 res=4 nodes=[3, 8, 9, 10]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=970.00] job_id=45 type=execution_finished nodes=[5, 6, 7, 12] start_time=825.0 subtime=215 actual_finish_time=970.0 req_finish_time=970.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=970.00] job_id=53 type=execution_start subtime=248 runtime=115 reqtime=115 res=3 nodes=[5, 6, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=970.00] job_id=61 type=execution_start subtime=277 runtime=53 reqtime=53 res=2 nodes=[11, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=985.00] job_id=52 type=execution_finished nodes=[3, 8, 9, 10] start_time=939.0 subtime=243 actual_finish_time=985.0 req_finish_time=985.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=985.00] job_id=54 type=execution_start subtime=248 runtime=97 reqtime=98 res=4 nodes=[3, 8, 9, 10]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=997.00] job_id=50 type=execution_finished nodes=[4, 13, 14, 15] start_time=875.0 subtime=235 actual_finish_time=997.0 req_finish_time=997.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=997.00] job_id=57 type=execution_start subtime=270 runtime=77 reqtime=77 res=4 nodes=[4, 13, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1011.00] job_id=51 type=execution_finished nodes=[0, 1, 2] start_time=918.0 subtime=243 actual_finish_time=1013.0 req_finish_time=1011.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1011.00] job_id=58 type=execution_start subtime=270 runtime=113 reqtime=113 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1023.00] job_id=61 type=execution_finished nodes=[11, 12] start_time=970.0 subtime=277 actual_finish_time=1023.0 req_finish_time=1023.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1023.00] job_id=98 type=execution_start subtime=483 runtime=49 reqtime=51 res=2 nodes=[11, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1072.00] job_id=98 type=execution_finished nodes=[11, 12] start_time=1023.0 subtime=483 actual_finish_time=1072.0 req_finish_time=1074.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1074.00] job_id=57 type=execution_finished nodes=[4, 13, 14, 15] start_time=997.0 subtime=270 actual_finish_time=1074.0 req_finish_time=1074.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1074.00] job_id=59 type=execution_start subtime=270 runtime=103 reqtime=102 res=5 nodes=[4, 11, 12, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1082.00] job_id=54 type=execution_finished nodes=[3, 8, 9, 10] start_time=985.0 subtime=248 actual_finish_time=1082.0 req_finish_time=1083.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1082.00] job_id=63 type=execution_start subtime=287 runtime=93 reqtime=93 res=4 nodes=[3, 8, 9, 10]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1085.00] job_id=53 type=execution_finished nodes=[5, 6, 7] start_time=970.0 subtime=248 actual_finish_time=1085.0 req_finish_time=1085.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1085.00] job_id=70 type=execution_start subtime=314 runtime=92 reqtime=94 res=2 nodes=[5, 6]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1124.00] job_id=58 type=execution_finished nodes=[0, 1, 2] start_time=1011.0 subtime=270 actual_finish_time=1124.0 req_finish_time=1124.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1124.00] job_id=64 type=execution_start subtime=288 runtime=64 reqtime=64 res=5 nodes=[0, 1, 2, 7, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1175.00] job_id=63 type=execution_finished nodes=[3, 8, 9, 10] start_time=1082.0 subtime=287 actual_finish_time=1175.0 req_finish_time=1175.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1175.00] job_id=67 type=execution_start subtime=303 runtime=89 reqtime=88 res=3 nodes=[3, 8, 9]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1176.00] job_id=59 type=execution_finished nodes=[4, 11, 12, 13, 14] start_time=1074.0 subtime=270 actual_finish_time=1177.0 req_finish_time=1176.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1176.00] job_id=65 type=execution_start subtime=289 runtime=56 reqtime=58 res=6 nodes=[4, 10, 11, 12, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1177.00] job_id=70 type=execution_finished nodes=[5, 6] start_time=1085.0 subtime=314 actual_finish_time=1177.0 req_finish_time=1179.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1177.00] job_id=78 type=execution_start subtime=352 runtime=98 reqtime=96 res=2 nodes=[5, 6]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1188.00] job_id=64 type=execution_finished nodes=[0, 1, 2, 7, 15] start_time=1124.0 subtime=288 actual_finish_time=1188.0 req_finish_time=1188.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1188.00] job_id=66 type=execution_start subtime=295 runtime=117 reqtime=117 res=4 nodes=[0, 1, 2, 7]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1232.00] job_id=65 type=execution_finished nodes=[4, 10, 11, 12, 13, 14] start_time=1176.0 subtime=289 actual_finish_time=1232.0 req_finish_time=1234.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1232.00] job_id=68 type=execution_start subtime=306 runtime=71 reqtime=72 res=3 nodes=[4, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1232.00] job_id=69 type=execution_start subtime=311 runtime=95 reqtime=95 res=3 nodes=[12, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1263.00] job_id=67 type=execution_finished nodes=[3, 8, 9] start_time=1175.0 subtime=303 actual_finish_time=1264.0 req_finish_time=1263.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1273.00] job_id=78 type=execution_finished nodes=[5, 6] start_time=1177.0 subtime=352 actual_finish_time=1275.0 req_finish_time=1273.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1273.00] job_id=71 type=execution_start subtime=325 runtime=72 reqtime=71 res=5 nodes=[3, 5, 6, 8, 9]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1303.00] job_id=68 type=execution_finished nodes=[4, 10, 11] start_time=1232.0 subtime=306 actual_finish_time=1303.0 req_finish_time=1304.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1303.00] job_id=72 type=execution_start subtime=327 runtime=65 reqtime=65 res=3 nodes=[4, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1305.00] job_id=66 type=execution_finished nodes=[0, 1, 2, 7] start_time=1188.0 subtime=295 actual_finish_time=1305.0 req_finish_time=1305.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1305.00] job_id=73 type=execution_start subtime=332 runtime=111 reqtime=110 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1305.00] job_id=93 type=execution_start subtime=457 runtime=99 reqtime=98 res=2 nodes=[7, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1327.00] job_id=69 type=execution_finished nodes=[12, 13, 14] start_time=1232.0 subtime=311 actual_finish_time=1327.0 req_finish_time=1327.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1327.00] job_id=74 type=execution_start subtime=332 runtime=31 reqtime=32 res=3 nodes=[12, 13, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1344.00] job_id=71 type=execution_finished nodes=[3, 5, 6, 8, 9] start_time=1273.0 subtime=325 actual_finish_time=1345.0 req_finish_time=1344.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1344.00] job_id=75 type=execution_start subtime=334 runtime=60 reqtime=61 res=4 nodes=[3, 5, 6, 8]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1358.00] job_id=74 type=execution_finished nodes=[12, 13, 14] start_time=1327.0 subtime=332 actual_finish_time=1358.0 req_finish_time=1359.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1358.00] job_id=76 type=execution_start subtime=341 runtime=62 reqtime=62 res=3 nodes=[9, 12, 13]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1368.00] job_id=72 type=execution_finished nodes=[4, 10, 11] start_time=1303.0 subtime=327 actual_finish_time=1368.0 req_finish_time=1368.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1368.00] job_id=77 type=execution_start subtime=350 runtime=98 reqtime=97 res=3 nodes=[4, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1403.00] job_id=93 type=execution_finished nodes=[7, 15] start_time=1305.0 subtime=457 actual_finish_time=1404.0 req_finish_time=1403.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1403.00] job_id=79 type=execution_start subtime=353 runtime=63 reqtime=63 res=3 nodes=[7, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1404.00] job_id=75 type=execution_finished nodes=[3, 5, 6, 8] start_time=1344.0 subtime=334 actual_finish_time=1404.0 req_finish_time=1405.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1415.00] job_id=73 type=execution_finished nodes=[0, 1, 2] start_time=1305.0 subtime=332 actual_finish_time=1416.0 req_finish_time=1415.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1415.00] job_id=80 type=execution_start subtime=373 runtime=98 reqtime=99 res=5 nodes=[0, 1, 2, 3, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1420.00] job_id=76 type=execution_finished nodes=[9, 12, 13] start_time=1358.0 subtime=341 actual_finish_time=1420.0 req_finish_time=1420.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1420.00] job_id=81 type=execution_start subtime=376 runtime=66 reqtime=67 res=4 nodes=[6, 8, 9, 12]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1465.00] job_id=77 type=execution_finished nodes=[4, 10, 11] start_time=1368.0 subtime=350 actual_finish_time=1466.0 req_finish_time=1465.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1466.00] job_id=79 type=execution_finished nodes=[7, 14, 15] start_time=1403.0 subtime=353 actual_finish_time=1466.0 req_finish_time=1466.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1466.00] job_id=82 type=execution_start subtime=376 runtime=70 reqtime=71 res=5 nodes=[4, 7, 10, 11, 13]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1486.00] job_id=81 type=execution_finished nodes=[6, 8, 9, 12] start_time=1420.0 subtime=376 actual_finish_time=1486.0 req_finish_time=1487.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1486.00] job_id=83 type=execution_start subtime=377 runtime=153 reqtime=154 res=3 nodes=[6, 8, 9]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1486.00] job_id=84 type=execution_start subtime=379 runtime=82 reqtime=83 res=3 nodes=[12, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1513.00] job_id=80 type=execution_finished nodes=[0, 1, 2, 3, 5] start_time=1415.0 subtime=373 actual_finish_time=1513.0 req_finish_time=1514.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1513.00] job_id=85 type=execution_start subtime=379 runtime=67 reqtime=67 res=3 nodes=[0, 1, 2]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1536.00] job_id=82 type=execution_finished nodes=[4, 7, 10, 11, 13] start_time=1466.0 subtime=376 actual_finish_time=1536.0 req_finish_time=1537.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1536.00] job_id=86 type=execution_start subtime=380 runtime=62 reqtime=61 res=3 nodes=[3, 4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1568.00] job_id=84 type=execution_finished nodes=[12, 14, 15] start_time=1486.0 subtime=379 actual_finish_time=1568.0 req_finish_time=1569.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1568.00] job_id=87 type=execution_start subtime=399 runtime=84 reqtime=82 res=5 nodes=[7, 10, 11, 12, 13]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1580.00] job_id=85 type=execution_finished nodes=[0, 1, 2] start_time=1513.0 subtime=379 actual_finish_time=1580.0 req_finish_time=1580.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1580.00] job_id=88 type=execution_start subtime=421 runtime=62 reqtime=62 res=5 nodes=[0, 1, 2, 14, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1597.00] job_id=86 type=execution_finished nodes=[3, 4, 5] start_time=1536.0 subtime=380 actual_finish_time=1598.0 req_finish_time=1597.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1597.00] job_id=89 type=execution_start subtime=424 runtime=83 reqtime=82 res=3 nodes=[3, 4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1639.00] job_id=83 type=execution_finished nodes=[6, 8, 9] start_time=1486.0 subtime=377 actual_finish_time=1639.0 req_finish_time=1640.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1639.00] job_id=92 type=execution_start subtime=453 runtime=105 reqtime=105 res=3 nodes=[6, 8, 9]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1642.00] job_id=88 type=execution_finished nodes=[0, 1, 2, 14, 15] start_time=1580.0 subtime=421 actual_finish_time=1642.0 req_finish_time=1642.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1642.00] job_id=90 type=execution_start subtime=431 runtime=54 reqtime=56 res=4 nodes=[0, 1, 2, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1650.00] job_id=87 type=execution_finished nodes=[7, 10, 11, 12, 13] start_time=1568.0 subtime=399 actual_finish_time=1652.0 req_finish_time=1650.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1650.00] job_id=91 type=execution_start subtime=437 runtime=99 reqtime=98 res=6 nodes=[7, 10, 11, 12, 13, 15]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1679.00] job_id=89 type=execution_finished nodes=[3, 4, 5] start_time=1597.0 subtime=424 actual_finish_time=1680.0 req_finish_time=1679.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1679.00] job_id=95 type=execution_start subtime=477 runtime=60 reqtime=59 res=3 nodes=[3, 4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1696.00] job_id=90 type=execution_finished nodes=[0, 1, 2, 14] start_time=1642.0 subtime=431 actual_finish_time=1696.0 req_finish_time=1698.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1696.00] job_id=94 type=execution_start subtime=464 runtime=66 reqtime=65 res=4 nodes=[0, 1, 2, 14]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1738.00] job_id=95 type=execution_finished nodes=[3, 4, 5] start_time=1679.0 subtime=477 actual_finish_time=1739.0 req_finish_time=1738.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1738.00] job_id=96 type=execution_start subtime=481 runtime=74 reqtime=75 res=3 nodes=[3, 4, 5]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1744.00] job_id=92 type=execution_finished nodes=[6, 8, 9] start_time=1639.0 subtime=453 actual_finish_time=1744.0 req_finish_time=1744.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1744.00] job_id=97 type=execution_start subtime=482 runtime=99 reqtime=98 res=3 nodes=[6, 8, 9]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1748.00] job_id=91 type=execution_finished nodes=[7, 10, 11, 12, 13, 15] start_time=1650.0 subtime=437 actual_finish_time=1749.0 req_finish_time=1748.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1748.00] job_id=99 type=execution_start subtime=497 runtime=58 reqtime=57 res=3 nodes=[7, 10, 11]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1761.00] job_id=94 type=execution_finished nodes=[0, 1, 2, 14] start_time=1696.0 subtime=464 actual_finish_time=1762.0 req_finish_time=1761.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1761.00] job_id=100 type=execution_start subtime=504 runtime=51 reqtime=53 res=5 nodes=[0, 1, 2, 12, 13]
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1805.00] job_id=99 type=execution_finished nodes=[7, 10, 11] start_time=1748.0 subtime=497 actual_finish_time=1806.0 req_finish_time=1805.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1812.00] job_id=96 type=execution_finished nodes=[3, 4, 5] start_time=1738.0 subtime=481 actual_finish_time=1812.0 req_finish_time=1813.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1812.00] job_id=100 type=execution_finished nodes=[0, 1, 2, 12, 13] start_time=1761.0 subtime=504 actual_finish_time=1812.0 req_finish_time=1814.0
# 2025-09-16 22:49:00 | INFO | runner:195 - [Time=1842.00] job_id=97 type=execution_finished nodes=[6, 8, 9] start_time=1744.0 subtime=482 actual_finish_time=1843.0 req_finish_time=1842.0
# 2025-09-16 22:49:00 | INFO | runner:164 - Simulation finished at time 1842.0.
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 0: Energy Consumption = 386820.0, Energy Effective = 378630.0, Energy Waste = 8190.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 1: Energy Consumption = 386820.0, Energy Effective = 378630.0, Energy Waste = 8190.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 2: Energy Consumption = 386820.0, Energy Effective = 376110.0, Energy Waste = 10710.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 3: Energy Consumption = 386820.0, Energy Effective = 358470.0, Energy Waste = 28350.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 4: Energy Consumption = 386820.0, Energy Effective = 360780.0, Energy Waste = 26040.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 5: Energy Consumption = 386820.0, Energy Effective = 368760.0, Energy Waste = 18060.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 6: Energy Consumption = 386820.0, Energy Effective = 379470.0, Energy Waste = 7350.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 7: Energy Consumption = 386820.0, Energy Effective = 360150.0, Energy Waste = 26670.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 8: Energy Consumption = 386820.0, Energy Effective = 377370.0, Energy Waste = 9450.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 9: Energy Consumption = 386820.0, Energy Effective = 377790.0, Energy Waste = 9030.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 10: Energy Consumption = 386820.0, Energy Effective = 365400.0, Energy Waste = 21420.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 11: Energy Consumption = 386820.0, Energy Effective = 347340.0, Energy Waste = 39480.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 12: Energy Consumption = 386820.0, Energy Effective = 347760.0, Energy Waste = 39060.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 13: Energy Consumption = 386820.0, Energy Effective = 344820.0, Energy Waste = 42000.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 14: Energy Consumption = 386820.0, Energy Effective = 337680.0, Energy Waste = 49140.0
# 2025-09-16 22:49:00 | INFO | runner:57 - Node 15: Energy Consumption = 386820.0, Energy Effective = 305130.0, Energy Waste = 81690.0
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 0: {'id': 0, 'active_idle': {'underclock_1': 0, 'base': 39.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1803.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 1: {'id': 1, 'active_idle': {'underclock_1': 0, 'base': 39.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1803.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 2: {'id': 2, 'active_idle': {'underclock_1': 0, 'base': 51.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1791.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 3: {'id': 3, 'active_idle': {'underclock_1': 0, 'base': 135.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1707.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 4: {'id': 4, 'active_idle': {'underclock_1': 0, 'base': 124.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1718.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 5: {'id': 5, 'active_idle': {'underclock_1': 0, 'base': 86.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1756.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 6: {'id': 6, 'active_idle': {'underclock_1': 0, 'base': 35.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1807.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 7: {'id': 7, 'active_idle': {'underclock_1': 0, 'base': 127.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1715.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 8: {'id': 8, 'active_idle': {'underclock_1': 0, 'base': 45.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1797.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 9: {'id': 9, 'active_idle': {'underclock_1': 0, 'base': 43.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1799.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 10: {'id': 10, 'active_idle': {'underclock_1': 0, 'base': 102.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1740.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 11: {'id': 11, 'active_idle': {'underclock_1': 0, 'base': 188.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1654.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 12: {'id': 12, 'active_idle': {'underclock_1': 0, 'base': 186.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1656.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 13: {'id': 13, 'active_idle': {'underclock_1': 0, 'base': 200.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1642.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 14: {'id': 14, 'active_idle': {'underclock_1': 0, 'base': 234.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1608.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:00 | INFO | runner:62 - Node 15: {'id': 15, 'active_idle': {'underclock_1': 0, 'base': 389.0, 'overclock_1': 0}, 'active_compute': {'underclock_1': 0, 'base': 1453.0, 'overclock_1': 0}, 'switching_off': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'switching_on': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}, 'sleeping': {'underclock_1': 0, 'base': 0, 'overclock_1': 0}}
# 2025-09-16 22:49:01 | INFO | runner:318 - Simulation completed. Logs saved to: results/generated
